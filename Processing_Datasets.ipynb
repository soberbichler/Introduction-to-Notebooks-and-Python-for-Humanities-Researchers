# %% [markdown]
# <a href="https://colab.research.google.com/github/soberbichler/Introduction-to-Notebooks-and-Python-for-Humanities-Researchers/blob/main/Processing_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Processing Datasets in Notebooks
#
#
# Created by Sarah Oberbichler [![ORCID](https://info.orcid.org/wp-content/uploads/2019/11/orcid_16x16.png)](https://orcid.org/0000-0002-1031-2759)

# %% [markdown]
# ## Importing Data to the Notebook
#
# In order to access our course data, we clone the course GitHub repository to this notebook. Do do so, run the *git clone* cell below:

# %%
# !git clone https://github.com/soberbichler/Introduction-to-Notebooks-and-Python-for-Humanities-Researchers.git
# Out:
# Cloning into 'Introduction-to-Notebooks-and-Python-for-Humanities-Researchers'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 51 (delta 19), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 7.96 MiB | 16.11 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %% [markdown]
# Now, when clicking on the file symbol on the left side of the Colab interface, you'll see the "Files" pane open up. Navigate through this pane to find and access the documents in the course file named "Introduction-to-Notebooks-and-Python-for-Humanities-Researchers". This folder should contain all the relevant materials. Copy the path for Data_erxercise_1.xlsx. To do so, click on the 3 points that appear when you hover over the document. Click on the 3 points and choose *copy path/Pfad kopieren*

# %%
# @markdown ##### If you copied the path, find the place where you can add it. Run the code and investigate the dataset
import pandas as pd

# Replace 'your_file.xlsx' with the actual path to your Excel file.
df = pd.read_excel('/content/Introduction-to-Notebooks-and-Python-for-Humanities-Researchers/Data_exercise_1.xlsx')

# Display the first few rows of the DataFrame to verify it's loaded correctly.
df.head(5)
# Out:
#                                              page_id  pagenumber  \
# 0  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-8f451700...          33
# 1  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-91c3b5fd...          18
# 2  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-966a0a0c...           1
# 3  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-9b22777c...          17
# 4  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-c7c7b5d0...           3
#
#                                          paper_title  \
# 0  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 1  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 2  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 3  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 4  Leipziger Tageblatt und Handelszeitung : Amtsb...
#
#                     provider_ddb_id  \
# 0  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 1  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 2  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 3  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 4  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
#
#                                             provider     zdb_id  \
# 0  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 1  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 2  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 3  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 4  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
#
#      publication_date place_of_distribution language  \
# 0 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 1 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 2 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 3 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 4 1909-01-01 12:00:00           ['Leipzig']  ['ger']
#
#                               thumbnail  \
# 0  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 1  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 2  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 3  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 4  fd3cfa5d-fb68-4650-adb0-26861c4ac643
#
#                                         pagefulltext  \
# 0  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 1  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 2  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 3  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 4  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
#
#                                             pagename  \
# 0  uuid-8f451700-f093-407d-bb23-daa1c9051bcd_DDB_...
# 1  uuid-91c3b5fd-4645-4d4b-96c6-6d58833b3954_DDB_...
# 2  uuid-966a0a0c-107a-4cce-9763-0b40e044f2e6_DDB_...
# 3  uuid-9b22777c-8649-4bb9-8a14-3288f34a8607_DDB_...
# 4  uuid-c7c7b5d0-595d-4b07-a160-7aafb1346ad2_DDB_...
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
# 4  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                    plainpagefulltext
# 0  8. Berlage Freitag, 1. Januar 1WV. Leipziger T...
# 1  Rr. 1. Jahrg. „Haben Die schon gelesen? In Cat...
# 2  «ezugtz-Vrritz M» M»»« I»»« M UeMM»» «» «schif...
# 3  4. Beilage Freitag, 1. Januar 1VVS. Leipziger ...
# 4  Freitag, 1. Januar 1»»». und russischen Hol»!"...

# %% [markdown]
# ##Investigate your data
#
# Now we can investigate the data. First let's check how many rows the excel file has:

# %%
# Length of the DataFrame

print(f"The DataFrame has {df.shape[0]} rows.")
# Out:
# The DataFrame has 902 rows.

# %%
# Only work with one of the column
df['paper_title']
# Out:
# 0      Leipziger Tageblatt und Handelszeitung : Amtsb...
# 1      Leipziger Tageblatt und Handelszeitung : Amtsb...
# 2      Leipziger Tageblatt und Handelszeitung : Amtsb...
# 3      Leipziger Tageblatt und Handelszeitung : Amtsb...
# 4      Leipziger Tageblatt und Handelszeitung : Amtsb...
#                              ...
# 897         General-Anzeiger für Halle und den Saalkreis
# 898         General-Anzeiger für Halle und den Saalkreis
# 899         General-Anzeiger für Halle und den Saalkreis
# 900                                Die Glocke. 1885-1933
# 901                                Die Glocke. 1885-1933
# Name: paper_title, Length: 902, dtype: object

# %%
# Find the number of different newspaper titles
num_unique_titles = df['paper_title'].nunique()

print(f"There are {num_unique_titles} different paper titles in the dataset.")
# Out:
# There are 145 different paper titles in the dataset.

# %%
# @markdown ##### **Exercise 1:** Now find the number of different places of distribution using the same method with the .nunique() function

# add your code here

# %%
# @markdown ##### **Exercise 2:** Find the column with the full text, load the first three rows of this column. Do you remember from the introduction how to find the first three letters in a string. We can use the same method to find the first three rows in a dataframe.

# add your code here

# %%
# print full text of one row of plainpagefulltext

print(df['plainpagefulltext'][0])
# Out:
ogt!. Bank in Plauen . 10 10 10 204,— —- 204,— Bank für Grundbesitz, Leipz. 8'/., 8'/. 8'/, 131,— 129,75 137,50 Leipziger Baubank . . . ca. 5'/.. 6 »Va 107,— 107,— 106,— Leipziger Jmmobiliengcs. . 9 9 9 165,50 168,— ch Eisenbahnaktien. Aussig-Teplitz ca.12 13 12 231,— ' 240 — 248,— - Genuß-Scheine 70 Kr. 80 K r. 70.» r. '.'85 — 1012 1063 Böhmische Nordbahu . . ca.5 6 133,— 12.;,-- — Bujchtiehradcr lüt. . . ca. 14" >, >4"/., 13'7°. 270,— 267,- 284,— lut. Ü . . ca. 13 13'/, 13 259,— — 284,— Gotthardbahn .... 6'/,—7 7 77s, 175,— 190,— 193 59 Graz-Köslach 6—7 7'/c 6 119,— 120,— >23,50 Jialiciiipt e Meridionalb. . 6 6 6 132,50 138,— 154,— Lcmberq-Czernow-Jassy . ca. 6 6 7 136.50 138,— 144,50 Lu re mb. Prince - Henri - B. ca. 5 6 67» 123,— 118,— 151 — Lübcck-Büchen 7'/g 8 8 172,— 179,— 195,— Oesterr.Noidw. lüt.^sgar.) ca.5 5'/. 5V< 109,— 109,50 116,50 - lut. K fElbt.) ca.5 5'/, 5'/, 108,50 — 116,— Oesterr.-Ungar. St. (Frz.) 6,6 67, 144,— 14-1,50 148,25 Oesterr. «ndbatm (Lomb.) 0 0 0 18,— 28,— >U,50 Prag-Dux, Prioritätsaktien ca.4 4 4 92,25 93,— 97,50 Jndustrieaktien. Gelsenkirchen, Aergw. . 9 12 11 190,- 193,25 — Hibcrnia, Bergwcikges. . 10 14 14 —— — Hamb. Paketf.-Aktieuges. . 0—2 6 10 112,— 115,75 157,75 Norddeutscher Lloyd . . 0 4V, 87, 89,75 184 — 131,— Allg. Denliche Kleiubahnges. ? 5'/z 5' . IV. — — — Allg. Lokal- u. Straßenb. . 8—8'/, 8 77, - "«» Große Leipz. Straßenbahn. 9 9 -> 176,— 175,— 186,- >? ...

# %% [markdown]
# # Change the size of your DataFrame
#
# We can also change the size of a DataFrame. Let's say we want to do some testing with only the first 10 rows of the dataset.

# %%
#Reduce your DataFrame to 10 rows
df_short = df[:10]

# %%
# @markdown ##### **Exercise 2:** Check if the DataFrame had been reduced to 10 rows

#add your code here

# %% [markdown]
# ## Search through your Dataframe
#
# We might also want to only works a specific aspect from our dataset. Let's assume, we only want to use newspapers that have been distributed in Berlin.

# %%
# Filter the DataFrame to include only rows where 'place_of_distribution' is 'Berlin'.
df_berlin = df[df['place_of_distribution'].str.contains('Leipzig', na = False)]

# Display the filtered DataFrame.
df_berlin.head()
# Out:
#                                              page_id  pagenumber  \
# 0  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-8f451700...          33
# 1  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-91c3b5fd...          18
# 2  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-966a0a0c...           1
# 3  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-9b22777c...          17
# 4  27NW3OP6PM6RMEI4HKTAD743YHZLZVP7-uuid-c7c7b5d0...           3
#
#                                          paper_title  \
# 0  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 1  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 2  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 3  Leipziger Tageblatt und Handelszeitung : Amtsb...
# 4  Leipziger Tageblatt und Handelszeitung : Amtsb...
#
#                     provider_ddb_id  \
# 0  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 1  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 2  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 3  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
# 4  265BI7NE7QBS4NQMZCCGIVLFR73OCOSL
#
#                                             provider     zdb_id  \
# 0  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 1  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 2  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 3  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
# 4  Sächsische Landesbibliothek - Staats- und Univ...  2843671-4
#
#      publication_date place_of_distribution language  \
# 0 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 1 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 2 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 3 1909-01-01 12:00:00           ['Leipzig']  ['ger']
# 4 1909-01-01 12:00:00           ['Leipzig']  ['ger']
#
#                               thumbnail  \
# 0  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 1  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 2  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 3  fd3cfa5d-fb68-4650-adb0-26861c4ac643
# 4  fd3cfa5d-fb68-4650-adb0-26861c4ac643
#
#                                         pagefulltext  \
# 0  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 1  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 2  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 3  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
# 4  ['/data/altos/27/NW/27NW3OP6PM6RMEI4HKTAD743YH...
#
#                                             pagename  \
# 0  uuid-8f451700-f093-407d-bb23-daa1c9051bcd_DDB_...
# 1  uuid-91c3b5fd-4645-4d4b-96c6-6d58833b3954_DDB_...
# 2  uuid-966a0a0c-107a-4cce-9763-0b40e044f2e6_DDB_...
# 3  uuid-9b22777c-8649-4bb9-8a14-3288f34a8607_DDB_...
# 4  uuid-c7c7b5d0-595d-4b07-a160-7aafb1346ad2_DDB_...
#
#                                    preview_reference  \
# 0  https://api.deutsche-digitale-bibliothek.de/bi...
# 1  https://api.deutsche-digitale-bibliothek.de/bi...
# 2  https://api.deutsche-digitale-bibliothek.de/bi...
# 3  https://api.deutsche-digitale-bibliothek.de/bi...
# 4  https://api.deutsche-digitale-bibliothek.de/bi...
#
#                                    plainpagefulltext
# 0  8. Berlage Freitag, 1. Januar 1WV. Leipziger T...
# 1  Rr. 1. Jahrg. „Haben Die schon gelesen? In Cat...
# 2  «ezugtz-Vrritz M» M»»« I»»« M UeMM»» «» «schif...
# 3  4. Beilage Freitag, 1. Januar 1VVS. Leipziger ...
# 4  Freitag, 1. Januar 1»»». und russischen Hol»!"...

# %%
# How many rows are these?

#add code here
# Out:
# 46

# %% [markdown]
# ## Exercise 3:
#
# Create a new DataFrame where each fulltext contains a specific word. For example "Katastrophe".

# %%
#add your code here:
